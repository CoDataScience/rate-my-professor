# %%
import pandas as pd

# %%
# Read in the data with pandas http://pandas.pydata.org
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

# %%
# Lets take a look at the data
train
# Out:
#               id     tid      dept        date forcredit     attendance  \
# 0       24228248  916674  Business  01/05/2015       Yes            NaN
# 1       24218909  916674  Business  01/02/2015       Yes      Mandatory
# 2       24215795  916674  Business  01/02/2015       Yes            NaN
# 3       24204179  916674  Business  12/30/2014       Yes  Not Mandatory
# 4       24198463  916674  Business  12/28/2014       Yes  Not Mandatory
# 5       24183494  916674  Business  12/24/2014       Yes      Mandatory
# 6       24175674  916674  Business  12/23/2014       Yes      Mandatory
# 7       24175029  916674  Business  12/23/2014       Yes  Not Mandatory
# 8       24172983  916674  Business  12/23/2014       Yes  Not Mandatory
# 9       24153400  916674  Business  12/20/2014       Yes      Mandatory
# 10      24152733  916674  Business  12/20/2014       Yes  Not Mandatory
# 11      24134516  916674  Business  12/18/2014       Yes      Mandatory
# 12      24118239  916674  Business  12/17/2014       Yes            NaN
# 13      24107988  916674  Business  12/16/2014       Yes      Mandatory
# 14      24103872  916674  Business  12/16/2014       Yes            NaN
# 15      24100083  916674  Business  12/16/2014       Yes      Mandatory
# 16      24094340  916674  Business  12/15/2014       Yes  Not Mandatory
# 17      24092937  916674  Business  12/15/2014       Yes  Not Mandatory
# 18      24092933  916674  Business  12/15/2014       Yes  Not Mandatory
# 19      24092283  916674  Business  12/15/2014       Yes            NaN
# 20      24081098  916674  Business  12/15/2014       Yes            NaN
# 21      24080158  916674  Business  12/15/2014       Yes      Mandatory
# 22      24079728  916674  Business  12/15/2014       Yes      Mandatory
# 23      24075858  916674  Business  12/14/2014       Yes            NaN
# 24      24074733  916674  Business  12/14/2014       Yes      Mandatory
# 25      24073808  916674  Business  12/14/2014       Yes            NaN
# 26      24070400  916674  Business  12/14/2014       Yes  Not Mandatory
# 27      24070348  916674  Business  12/14/2014       Yes  Not Mandatory
# 28      24069718  916674  Business  12/13/2014       Yes  Not Mandatory
# 29      24068588  916674  Business  12/13/2014       Yes      Mandatory
# ...          ...     ...       ...         ...       ...            ...
# 117781    480315     186   Science  01/08/2003       NaN            NaN
# 117782    473637     186   Science  01/06/2003       NaN            NaN
# 117783    472715     186   Science  01/05/2003       NaN            NaN
# 117784    472170     186   Science  01/05/2003       NaN            NaN
# 117785    467729     186   Science  01/01/2003       NaN            NaN
# 117786    455011     186   Science  12/20/2002       NaN            NaN
# 117787    455007     186   Science  12/20/2002       NaN            NaN
# 117788    439675     186   Science  12/16/2002       NaN            NaN
# 117789    417367     186   Science  12/11/2002       NaN            NaN
# 117790    399045     186   Science  12/05/2002       NaN            NaN
# 117791    386694     186   Science  12/02/2002       NaN            NaN
# 117792    352334     186   Science  11/18/2002       NaN            NaN
# 117793    283164     186   Science  10/09/2002       NaN            NaN
# 117794    281069     186   Science  10/08/2002       NaN            NaN
# 117795    249114     186   Science  08/23/2002       NaN            NaN
# 117796    249113     186   Science  08/23/2002       NaN            NaN
# 117797    246521     186   Science  08/15/2002       NaN            NaN
# 117798    238737     186   Science  07/24/2002       NaN            NaN
# 117799    214986     186   Science  05/21/2002       NaN            NaN
# 117800    205560     186   Science  05/09/2002       NaN            NaN
# 117801    191382     186   Science  04/26/2002       NaN            NaN
# 117802    181766     186   Science  04/18/2002       NaN            NaN
# 117803    174008     186   Science  04/12/2002       NaN            NaN
# 117804    157330     186   Science  04/02/2002       NaN            NaN
# 117805    149212     186   Science  03/26/2002       NaN            NaN
# 117806    147271     186   Science  03/25/2002       NaN            NaN
# 117807    138665     186   Science  03/17/2002       NaN            NaN
# 117808    133473     186   Science  03/12/2002       NaN            NaN
# 117809    117473     186   Science  02/19/2002       NaN            NaN
# 117810     84499     186   Science  01/23/2002       NaN            NaN
#
#                   textbookuse          interest         grade  \
# 0            It's a must have    Really into it           NaN
# 1            It's a must have  Sorta interested             A
# 2        Essential to passing    Really into it           NaN
# 3        Essential to passing  Sorta interested           NaN
# 4       You need it sometimes  Sorta interested             A
# 5        Essential to passing    Really into it           NaN
# 6            It's a must have  Sorta interested  Not sure yet
# 7       You need it sometimes               Meh             A
# 8            It's a must have  Sorta interested            C+
# 9            It's a must have    Really into it  Not sure yet
# 10       Essential to passing  Sorta interested  Not sure yet
# 11       Essential to passing      It's my life             A
# 12           It's a must have  Sorta interested           NaN
# 13           It's a must have               Low           NaN
# 14       Essential to passing  Sorta interested           NaN
# 15       Essential to passing      It's my life  Not sure yet
# 16           It's a must have               Low           NaN
# 17       Essential to passing  Sorta interested           NaN
# 18           It's a must have    Really into it           NaN
# 19           It's a must have  Sorta interested           NaN
# 20       Essential to passing    Really into it           NaN
# 21           It's a must have               Low             C
# 22       Essential to passing  Sorta interested             A
# 23       Essential to passing  Sorta interested           NaN
# 24       Essential to passing    Really into it             A
# 25           It's a must have               Low           NaN
# 26       Essential to passing               Meh            A-
# 27       Essential to passing               Meh             B
# 28       Essential to passing    Really into it           NaN
# 29       Essential to passing  Sorta interested           NaN
# ...                       ...               ...           ...
# 117781                    NaN               NaN           NaN
# 117782                    NaN               NaN           NaN
# 117783                    NaN               NaN           NaN
# 117784                    NaN               NaN           NaN
# 117785                    NaN               NaN           NaN
# 117786                    NaN               NaN           NaN
# 117787                    NaN               NaN           NaN
# 117788                    NaN               NaN           NaN
# 117789                    NaN               NaN           NaN
# 117790                    NaN               NaN           NaN
# 117791                    NaN               NaN           NaN
# 117792                    NaN               NaN           NaN
# 117793                    NaN               NaN           NaN
# 117794                    NaN               NaN           NaN
# 117795                    NaN               NaN           NaN
# 117796                    NaN               NaN           NaN
# 117797                    NaN               NaN           NaN
# 117798                    NaN               NaN           NaN
# 117799                    NaN               NaN           NaN
# 117800                    NaN               NaN           NaN
# 117801                    NaN               NaN           NaN
# 117802                    NaN               NaN           NaN
# 117803                    NaN               NaN           NaN
# 117804                    NaN               NaN           NaN
# 117805                    NaN               NaN           NaN
# 117806                    NaN               NaN           NaN
# 117807                    NaN               NaN           NaN
# 117808                    NaN               NaN           NaN
# 117809                    NaN               NaN           NaN
# 117810                    NaN               NaN           NaN
#
#                                                      tags  \
# 0       ["Would take again", "Hilarious", "Tests are t...
# 1       ["Skip class? You won't pass.", "Tests are tou...
# 2       ["Hilarious", "Would take again", "Skip class?...
# 3                ["Tests are tough", "Get ready to read"]
# 4       ["Inspirational", "Hilarious", "Skip class? Yo...
# 5       ["Clear grading criteria", "Would take again",...
# 6       ["Skip class? You won't pass.", "Participation...
# 7       ["Get ready to read", "Participation matters",...
# 8        ["Skip class? You won't pass.", "Inspirational"]
# 9       ["Skip class? You won't pass.", "Hilarious", "...
# 10      ["Skip class? You won't pass.", "Inspirational...
# 11           ["Hilarious", "Skip class? You won't pass."]
# 12                        ["Skip class? You won't pass."]
# 13      ["Inspirational", "Tests are tough", "Skip cla...
# 14      ["Respected by students", "Inspirational", "Te...
# 15      ["Hilarious", "Respected by students", "Inspir...
# 16      ["Clear grading criteria", "Inspirational", "H...
# 17      ["Clear grading criteria", "Would take again",...
# 18      ["Skip class? You won't pass.", "Inspirational...
# 19      ["There for you", "Skip class? You won't pass....
# 20      ["Hilarious", "Amazing lectures", "Would take ...
# 21      ["Respected by students", "Hilarious", "Tests ...
# 22      ["Tests are tough", "Inspirational", "Respecte...
# 23      ["Get ready to read", "Skip class? You won't p...
# 24                                                     []
# 25      ["Skip class? You won't pass.", "Lectures are ...
# 26      ["Tough Grader", "Tests are tough", "Skip clas...
# 27      ["Skip class? You won't pass.", "Lectures are ...
# 28      ["Skip class? You won't pass.", "Respected by ...
# 29      ["Get ready to read", "Skip class? You won't p...
# ...                                                   ...
# 117781                                                 []
# 117782                                                 []
# 117783                                                 []
# 117784                                                 []
# 117785                                                 []
# 117786                                                 []
# 117787                                                 []
# 117788                                                 []
# 117789                                                 []
# 117790                                                 []
# 117791                                                 []
# 117792                                                 []
# 117793                                                 []
# 117794                                                 []
# 117795                                                 []
# 117796                                                 []
# 117797                                                 []
# 117798                                                 []
# 117799                                                 []
# 117800                                                 []
# 117801                                                 []
# 117802                                                 []
# 117803                                                 []
# 117804                                                 []
# 117805                                                 []
# 117806                                                 []
# 117807                                                 []
# 117808                                                 []
# 117809                                                 []
# 117810                                                 []
#
#                                                  comments  helpcount  \
# 0       Great Professor My wife took this class twice ...          0
# 1       Great Professor Study the notes from class and...          0
# 2       Brother Brau is a great guy He gives great spi...          1
# 3       People rave about Brau but I personally dont g...         18
# 4       This class doesnt have much homework which was...          1
# 5       Bro Brau definitely knows what he is doing  I ...          1
# 6       Lectures are long but he does a good job of br...          0
# 7       Can be a good buddy but not a good professor T...         10
# 8       I love Brother Brau for his spiritual thoughts...         10
# 9       Professor Brau really cares  If he talks about...          0
# 10      Professor Brau makes finance enjoyable Good cl...          5
# 11      He is an awesome professor  He makes going to ...          0
# 12      Not a fan of the subject but thought this was ...          0
# 13      Brau is a great instructor but he his tests ar...          0
# 14      Brau is incredibly inspirational He has a spir...          0
# 15      His lectures were awesome He drops some spirit...          0
# 16      Professor Brau is a great professor You will a...          0
# 17      This class wasnt necessarily easy but if you p...          0
# 18      Best professor Ive had at BYU He actually care...          0
# 19      Professor Brau is a great guy I loved his spir...          1
# 20                                               Nice Guy          0
# 21      I love Brother Brau as a teacher he really car...          1
# 22      Dont expect this course to be easy  But Bro Br...          0
# 23      Loved the teacher loved the class lectures not...          0
# 24      Prof Brau is a good guy He really cares about ...          0
# 25      Brau is a good person to maybe talk to or hang...          2
# 26      Wastes so much time with his stupid spiritual ...          6
# 27      Worst Professor no worst teacher I have ever h...          1
# 28                                        Dude is awesome          0
# 29      I liked Brother Brau His class was very straig...          0
# ...                                                   ...        ...
# 117781  Very nice and funny dont take class if you don...          0
# 117782           Great teacherget in his class of you can          0
# 117783                       raaarrr could not stay awake          0
# 117784  Class gets progressively harder  Dont let your...          0
# 117785  Very unhelpful teacher quite a smartass and ha...          0
# 117786  incredible prof knows what he is talking about...          0
# 117787  outstanding prof class gets tough as yr goes o...          0
# 117788  He makes you feel stupid if you dont understan...          0
# 117789  Nice to somedoesnt make eye contact VERY hard ...          0
# 117790  Very unhelpful hard class He is very narrow mi...          0
# 117791  Awesome prof very funny learned a lot in my th...          0
# 117792          Fun class best chem teacher in department          0
# 117793                                        No Comments          0
# 117794  Nice guy helpful guy but difficult class if yo...          0
# 117795  might be an awesome teacher wont help your gra...          0
# 117796  he might be an  awesome  teacher it wont help ...          0
# 117797              very helpful and nice knows his stuff          0
# 117798  Nice but he is very stuck in his ways and cant...          0
# 117799  Acted like he cared but wasnt willing to bend ...          0
# 117800  very hard is very intelligent and lectures are...          0
# 117801  Excellent  You must work very hard but he will...          0
# 117802               INCREDIBLE PROF HIGHLY RECOMMEND HIM          0
# 117803  Very hard class he taught the material well I ...          0
# 117804    great teacher hard tests dont skip his lectures          0
# 117805  claims to want to help but turns away students...          0
# 117806               VERY rude and TESTS are way too hard          0
# 117807  3 years later still remember the style you tau...          0
# 117808  Hes so great  Ive never learned so much in one...          0
# 117809  I thought he was awsome I learned and understo...          0
# 117810                        I LOVE HIM Hes the greatest          0
#
#         nothelpcount online  profgender  profhotness  helpfulness  clarity  \
# 0                 10    NaN           0            0            4        5
# 1                  1    NaN           0            0            4        4
# 2                  2    NaN           0            0            4        4
# 3                  6    NaN           0            0            3        1
# 4                  0    NaN           0            0            4        4
# 5                  1    NaN           0            0            4        4
# 6                  0    NaN           0            0            5        4
# 7                  5    NaN           0            0            1        1
# 8                  1    NaN           0            0            3        2
# 9                  0    NaN           0            0            5        5
# 10                 0    NaN           0            0            4        2
# 11                 0    NaN           0            0            5        4
# 12                 0    NaN           0            0            4        4
# 13                 0    NaN           0            0            4        3
# 14                 0    NaN           0            0            5        5
# 15                 0    NaN           0            0            5        5
# 16                 1    NaN           0            0            4        3
# 17                 0    NaN           0            0            5        4
# 18                 0    NaN           0            0            5        5
# 19                 0    NaN           0            0            4        2
# 20                 1    NaN           0            0            4        5
# 21                 0    NaN           0            0            5        1
# 22                 0    NaN           0            0            4        5
# 23                 0    NaN           0            0            4        4
# 24                 0    NaN           0            0            3        3
# 25                 0    NaN           0            0            2        1
# 26                 5    NaN           0            0            1        1
# 27                 5    NaN           0            0            2        1
# 28                 1    NaN           0            0            4        4
# 29                 0    NaN           0            0            5        4
# ...              ...    ...         ...          ...          ...      ...
# 117781             0    NaN           0            0            4        4
# 117782             0    NaN           0            0            5        5
# 117783             0    NaN           0            0            2        3
# 117784             0    NaN           0            0            4        5
# 117785             0    NaN           0            0            1        1
# 117786             0    NaN           0            0            5        5
# 117787             0    NaN           0            0            5        5
# 117788             0    NaN           0            0            1        2
# 117789             0    NaN           0            0            4        1
# 117790             0    NaN           0            0            1        3
# 117791             0    NaN           0            0            5        5
# 117792             0    NaN           0            0            5        5
# 117793             0    NaN           0            0            5        2
# 117794             0    NaN           0            0            5        4
# 117795             0    NaN           0            0            3        3
# 117796             0    NaN           0            0            4        4
# 117797             0    NaN           0            0            5        4
# 117798             0    NaN           0            0            3        4
# 117799             0    NaN           0            0            4        3
# 117800             0    NaN           0            0            5        2
# 117801             0    NaN           0            0            5        4
# 117802             0    NaN           0            0            5        5
# 117803             0    NaN           0            0            4        5
# 117804             0    NaN           0            0            3        5
# 117805             0    NaN           0            0            1        2
# 117806             0    NaN           0            0            1        4
# 117807             0    NaN           0            0            5        4
# 117808             0    NaN           0            0            4        5
# 117809             0    NaN           0            0            5        5
# 117810             0    NaN           0            0            5        5
#
#         easiness  quality
# 0              3        9
# 1              2        8
# 2              3        8
# 3              2        4
# 4              4        8
# 5              3        8
# 6              3        9
# 7              5        2
# 8              1        5
# 9              2       10
# 10             1        6
# 11             3        9
# 12             3        8
# 13             2        7
# 14             2       10
# 15             5       10
# 16             3        7
# 17             4        9
# 18             4       10
# 19             2        6
# 20             3        9
# 21             2        6
# 22             3        9
# 23             2        8
# 24             3        6
# 25             2        3
# 26             1        2
# 27             1        3
# 28             3        8
# 29             4        9
# ...          ...      ...
# 117781         1        8
# 117782         3       10
# 117783         1        5
# 117784         2        9
# 117785         1        2
# 117786         3       10
# 117787         2       10
# 117788         1        3
# 117789         1        5
# 117790         1        4
# 117791         2       10
# 117792         3       10
# 117793         1        7
# 117794         1        9
# 117795         1        6
# 117796         1        8
# 117797         3        9
# 117798         2        7
# 117799         1        7
# 117800         1        7
# 117801         2        9
# 117802         3       10
# 117803         2        9
# 117804         3        8
# 117805         1        3
# 117806         1        5
# 117807         1        9
# 117808         2        9
# 117809         3       10
# 117810         1       10
#
# [117811 rows x 20 columns]

# %% [markdown]
# # Notes
# In training the id doesn't matter, but this is the column to keep for predictions on test.csv. Aside from that quality is the most important column since its what we are trying to predict
#
# For this tutorial/baseline lets use a simple unigram model of the comments with logistic regresssion

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import Pipeline
from sklearn.grid_search import GridSearchCV

# %%
# Make a pipeline to do unigrams then run linear regression
# http://scikit-learn.org/stable/modules/generated/sklearn.pipeline.Pipeline.html
pipeline = Pipeline([
        ('cv', CountVectorizer()),
        ('regression', LinearRegression())
])

# Use the cross validation feature of sklearn to get a good estimate of the error.
# Before feeding in the comments we fill any nulls as empty strings
# http://scikit-learn.org/stable/modules/generated/sklearn.grid_search.GridSearchCV.html
cv = GridSearchCV(
    pipeline, {}
).fit(train['comments'].fillna(''), train['quality'])
cv
# Out:
# GridSearchCV(cv=None, error_score='raise',
#        estimator=Pipeline(steps=[('cv', CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), preprocessor=None, stop_words=No...ne)), ('regression', LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False))]),
#        fit_params={}, iid=True, n_jobs=1, param_grid={},
#        pre_dispatch='2*n_jobs', refit=True, scoring=None, verbose=0)

# %%
# Output the best score
cv.best_score_
# Out:
# 0.20017425535942762

# %%
# Make training predictions
predictions = cv.predict(test['comments'].fillna(''))

# %%
# Lets take a quick look at the predictions to make sure they are sensible, seems like it
predictions
# Out:
# array([ 10.39862571,   7.60000079,   8.27296863, ...,   8.35007346,
#          8.50790916,   6.35229394])

# %%
# Finally lets write out the predictions with their id's

with open('predictions.csv', 'w') as f:
    for row_id, prediction in zip(test['id'], predictions):
        f.write('{},{}\n'.format(row_id, prediction))
